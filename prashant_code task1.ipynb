# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# website url
url = "https://books.toscrape.com/catalogue/category/books/travel_2/index.html"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
books = soup.find_all("article", class_="product_pod")
book_names = []
prices = []
ratings = []
availability = []

for book in books:
    
    # Book name
    name = book.h3.a["title"]
    
    # Price
    price = book.find("p", class_="price_color").text
    
    # Rating
    rating = book.find("p")["class"][1]
    
    # Availability
    stock = book.find("p", class_="instock availability").text.strip()

    # Store data
    book_names.append(name)
    prices.append(price)
    ratings.append(rating)
    availability.append(stock)

# hear i am creating sataframe to maintain data in orgniged wayi
df = pd.DataFrame({
    "Book Name": book_names,
    "Price": prices,
    "Rating": ratings,
    "Availability": availability
})


df
# Out:
#                                             Book Name    Price Rating  \
# 0                             It's Only the Himalayas  Â£45.17    Two
# 1   Full Moon over Noahâs Ark: An Odyssey to Mou...  Â£49.43   Four
# 2   See America: A Celebration of Our National Par...  Â£48.87  Three
# 3   Vagabonding: An Uncommon Guide to the Art of L...  Â£36.94    Two
# 4                                Under the Tuscan Sun  Â£37.33  Three
# 5                                  A Summer In Europe  Â£44.34    Two
# 6                            The Great Railway Bazaar  Â£30.54    One
# 7                    A Year in Provence (Provence #1)  Â£56.88   Four
# 8   The Road to Little Dribbling: Adventures of an...  Â£23.21    One
# 9           Neither Here nor There: Travels in Europe  Â£38.95  Three
# 10                 1,000 Places to See Before You Die  Â£26.08   Five
#
#    Availability
# 0      In stock
# 1      In stock
# 2      In stock
# 3      In stock
# 4      In stock
# 5      In stock
# 6      In stock
# 7      In stock
# 8      In stock
# 9      In stock
# 10     In stock

# %%
df.to_csv(r"D:\html\task1_books_data_screeming.csv", index=False)

print("File saved successfully")
# Out:
# File saved successfully
